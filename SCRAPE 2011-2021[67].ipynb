# %%
#package imports
from bs4 import BeautifulSoup 
import lxml
import requests as request
import pandas as pd

#access the url and assign
url = 'https://www.pgatour.com/content/pgatour/stats/stat.159.y2021.html'
request.get(url)
page = request.get(url)

#use bs4 
soup = BeautifulSoup(page.text, 'html')

#find the table
table_data = soup.find('table', class_ ='table-styled')

#assign the headers
headers = []
for i in table_data.find_all('th'): #find the positions of the headers
    title = i.text #convert to text
    headers.append(title)

df_2021 = pd.DataFrame(columns = headers)

#grab the contents of the table
for j in table_data.find_all('tr')[1:]:
        row_data = j.find_all('td')
        row = [tr.text for tr in row_data]
        length = len(df_2021)
        df_2021.loc[length] = row
df_2021
# Out:
#      RANK THIS WEEK \n                                RANK LAST WEEK  \
# 0       \n        1                                      \n        1
# 1       \n        2                                      \n        2
# 2       \n        3                                      \n        3
# 3       \n        4                                      \n        4
# 4       \n        5                                      \n        5
# ..              ...                                              ...
# 629  \n        T628                                   \n        T628
# 630   \n        631                                    \n        631
# 631   \n        632                                    \n        632
# 632   \n        633                                    \n        633
# 633   \n        634                                    \n        634
#
#                PLAYER NAME ROUNDS DISTANCE       TOURNAMENT ROUND HOLE COURSE
# 0         \nLee Westwood\n     65      425     Byron Nelson     3    8    894
# 1        \nCameron Champ\n     79      424           Sentry     4    7    656
# 2          \nConnor Syme\n      2      423  U.S. Open(2020)     2    4    891
# 3       \nDustin Johnson\n     75      419  U.S. Open(2020)     4    9    891
# 4    \nBryson DeChambeau\n     83      414           Sentry     2   12    656
# ..                     ...    ...      ...              ...   ...  ...    ...
# 629    \nSantiago Tarrio\n      2      272         Mayakoba     2    5    733
# 630        \nSteve Jones\n      2      271         The Amex     1    2    704
# 631          \nFred Funk\n      4      267          Bermuda     3   12    765
# 632         \nLarry Mize\n      4      266   Masters (2020)     1    1    014
# 633          \nJeff Roth\n      2      265  Rocket Mortgage     2    2    876
#
# [634 rows x 9 columns]

# %%
#package imports
from bs4 import BeautifulSoup 
import lxml
import requests as request
import pandas as pd

#access the url and assign
url = 'https://www.pgatour.com/content/pgatour/stats/stat.159.y2020.html'
request.get(url)
page = request.get(url)

#use bs4 
soup = BeautifulSoup(page.text, 'html')

#find the table
table_data = soup.find('table', class_ ='table-styled')

#assign the headers
headers = []
for i in table_data.find_all('th'): #find the positions of the headers
    title = i.text #convert to text
    headers.append(title)

df_2020 = pd.DataFrame(columns = headers)

#grab the contents of the table
for j in table_data.find_all('tr')[1:]:
        row_data = j.find_all('td')
        row = [tr.text for tr in row_data]
        length = len(df_2020)
        df_2020.loc[length] = row
df_2020
# Out:
#      RANK THIS WEEK \n                                RANK LAST WEEK  \
# 0       \n        1                                      \n        1
# 1      \n        T2                                     \n        T2
# 2      \n        T2                                     \n        T2
# 3      \n        T4                                     \n        T4
# 4      \n        T4                                     \n        T4
# ..              ...                                              ...
# 480  \n        T481                                   \n        T481
# 481  \n        T481                                   \n        T481
# 482  \n        T481                                   \n        T481
# 483   \n        484                                    \n        484
# 484   \n        485                                    \n        485
#
#              PLAYER NAME ROUNDS DISTANCE    TOURNAMENT ROUND HOLE COURSE
# 0      \nJustin Thomas\n     66      449    WGC-Mexico     4    2    240
# 1      \nRickie Fowler\n     44      431  the Memorial     1   17    023
# 2       \nBubba Watson\n     66      431  the Memorial     4   17    023
# 3      \nSergio Garcia\n     44      429  the Memorial     4   17    023
# 4      \nLanto Griffin\n     96      429        Sentry     1    7    656
# ..                   ...    ...      ...           ...   ...  ...    ...
# 480      \nDavid Duval\n      1      275  Pebble Beach     1   10    005
# 481  \nEdward Figueroa\n      2      275   Puerto Rico     2    2    742
# 482        \nJeff Roth\n      2      275     PGA Champ     2    4    895
# 483        \nFred Funk\n      2      253       Bermuda     2    2    765
# 484   \nDwayne Pearman\n      2      243       Bermuda     2   12    765
#
# [485 rows x 9 columns]

# %%
#package imports
from bs4 import BeautifulSoup 
import lxml
import requests as request
import pandas as pd

#access the url and assign
url = 'https://www.pgatour.com/content/pgatour/stats/stat.159.y2019.html'
request.get(url)
page = request.get(url)

#use bs4 
soup = BeautifulSoup(page.text, 'html')

#find the table
table_data = soup.find('table', class_ ='table-styled')

#assign the headers
headers = []
for i in table_data.find_all('th'): #find the positions of the headers
    title = i.text #convert to text
    headers.append(title)

df_2019 = pd.DataFrame(columns = headers)

#grab the contents of the table
for j in table_data.find_all('tr')[1:]:
        row_data = j.find_all('td')
        row = [tr.text for tr in row_data]
        length = len(df_2019)
        df_2019.loc[length] = row
df_2019
# Out:
#     RANK THIS WEEK \n                                RANK LAST WEEK  \
# 0      \n        1                                      \n        1
# 1      \n        2                                      \n        2
# 2      \n        3                                      \n        3
# 3     \n        T4                                     \n        T4
# 4     \n        T4                                     \n        T4
# ..             ...                                              ...
# 614  \n        615                                    \n        615
# 615  \n        616                                    \n        616
# 616  \n        617                                    \n        617
# 617  \n        618                                    \n        618
# 618  \n        619                                    \n        619
#
#                    PLAYER NAME ROUNDS DISTANCE    TOURNAMENT ROUND HOLE COURSE
# 0          \n    Justin Thomas     75      457    WGC-Mexico     3   10    240
# 1           \n    Bubba Watson     65      455     U.S. Open     2    2    666
# 2        \n    Patrick Rodgers     55      428  Safeway Open     4   13    552
# 3          \n    Wyndham Clark     87      424  Safeway Open     4   13    552
# 4       \n    Maverick McNealy      6      424  Safeway Open     4   13    552
# ..                         ...    ...      ...           ...   ...  ...    ...
# 614          \n    Ian Woosnam      2      275       Masters     1    1    014
# 615         \n    Craig Bowden      2      273     PGA Champ     2    1    880
# 616          \n    Spike McRoy      2      270   Puerto Rico     2    2    742
# 617  \n    José María Olazábal      2      262       Masters     2    1    014
# 618           \n    Larry Mize      2      255       Masters     2    1    014
#
# [619 rows x 9 columns]

# %%
#package imports
from bs4 import BeautifulSoup 
import lxml
import requests as request
import pandas as pd

#access the url and assign
url = 'https://www.pgatour.com/content/pgatour/stats/stat.159.y2018.html'
request.get(url)
page = request.get(url)

#use bs4 
soup = BeautifulSoup(page.text, 'html')

#find the table
table_data = soup.find('table', class_ ='table-styled')

#assign the headers
headers = []
for i in table_data.find_all('th'): #find the positions of the headers
    title = i.text #convert to text
    headers.append(title)

df_2018 = pd.DataFrame(columns = headers)

#grab the contents of the table
for j in table_data.find_all('tr')[1:]:
        row_data = j.find_all('td')
        row = [tr.text for tr in row_data]
        length = len(df_2018)
        df_2018.loc[length] = row
df_2018
# Out:
#      RANK THIS WEEK \n                                RANK LAST WEEK  \
# 0       \n        1                                      \n        1
# 1      \n        T2                                     \n        T2
# 2      \n        T2                                     \n        T2
# 3       \n        4                                      \n        4
# 4      \n        T5                                     \n        T5
# ..              ...                                              ...
# 621   \n        622                                    \n        622
# 622  \n        T623                                   \n        T623
# 623  \n        T623                                   \n        T623
# 624   \n        625                                    \n        625
# 625   \n        626                                    \n        626
#
#              PLAYER NAME ROUNDS DISTANCE       TOURNAMENT ROUND HOLE COURSE
# 0      \nMichael Block\n      9      433        U.S. Open     1    3    618
# 1     \nDustin Johnson\n     77      430    Sentry T of C     4   12    656
# 2    \nHudson Swafford\n     73      430    Sentry T of C     3    7    656
# 3    \nJhonattan Vegas\n     92      424    Sentry T of C     3    7    656
# 4       \nKevin Kisner\n     89      423    Sentry T of C     2    7    656
# ..                   ...    ...      ...              ...   ...  ...    ...
# 621     \nCraig Bowden\n      2      282  PGA Championshi     1    8    534
# 622         \nGlen Day\n      2      280     RBC Heritage     1   16    012
# 623       \nLarry Mize\n      2      280          Masters     1    2    014
# 624    \nJavier Colomo\n      2      277         Mayakoba     1   13    733
# 625      \nMark Brooks\n      3      274    CareerBuilder     2   13    202
#
# [626 rows x 9 columns]

# %%
#package imports
from bs4 import BeautifulSoup 
import lxml
import requests as request
import pandas as pd

#access the url and assign
url = 'https://www.pgatour.com/content/pgatour/stats/stat.159.y2017.html'
request.get(url)
page = request.get(url)

#use bs4 
soup = BeautifulSoup(page.text, 'html')

#find the table
table_data = soup.find('table', class_ ='table-styled')

#assign the headers
headers = []
for i in table_data.find_all('th'): #find the positions of the headers
    title = i.text #convert to text
    headers.append(title)

df_2017 = pd.DataFrame(columns = headers)

#grab the contents of the table
for j in table_data.find_all('tr')[1:]:
        row_data = j.find_all('td')
        row = [tr.text for tr in row_data]
        length = len(df_2017)
        df_2017.loc[length] = row
df_2017
# Out:
#      RANK THIS WEEK \n                                RANK LAST WEEK  \
# 0       \n        1                                      \n        1
# 1       \n        2                                      \n        2
# 2       \n        3                                      \n        3
# 3       \n        4                                      \n        4
# 4       \n        5                                      \n        5
# ..              ...                                              ...
# 605  \n        T604                                   \n        T604
# 606   \n        607                                    \n        607
# 607   \n        608                                    \n        608
# 608   \n        609                                    \n        609
# 609   \n        610                                    \n        610
#
#              PLAYER NAME ROUNDS DISTANCE       TOURNAMENT ROUND HOLE COURSE
# 0     \nDustin Johnson\n     77      439  WGC-Bridgestone     1   16    036
# 1         \nAdam Scott\n     58      435  WGC-Bridgestone     2   16    036
# 2    \nHudson Swafford\n     94      433  WGC-Bridgestone     1   16    036
# 3         \nScott Hend\n     22      424  WGC-Bridgestone     1   16    036
# 4      \nBrooks Koepka\n     88      420  WGC-Bridgestone     4   16    036
# ..                   ...    ...      ...              ...   ...  ...    ...
# 605      \nIan Woosnam\n      2      279          Masters     1    1    014
# 606        \nToto Gana\n      2      275          Masters     2    1    014
# 607     \nHuilin Zhang\n      4      268  WGC-HSBC Champ.     2   14    766
# 608      \nMark Brooks\n      3      263    CareerBuilder     1   15    704
# 609   \nMatthew Millar\n      4      258  WGC-HSBC Champ.     2   14    766
#
# [610 rows x 9 columns]

# %%
#package imports
from bs4 import BeautifulSoup 
import lxml
import requests as request
import pandas as pd

#access the url and assign
url = 'https://www.pgatour.com/content/pgatour/stats/stat.159.y2016.html'
request.get(url)
page = request.get(url)

#use bs4 
soup = BeautifulSoup(page.text, 'html')

#find the table
table_data = soup.find('table', class_ ='table-styled')

#assign the headers
headers = []
for i in table_data.find_all('th'): #find the positions of the headers
    title = i.text #convert to text
    headers.append(title)

df_2016 = pd.DataFrame(columns = headers)

#grab the contents of the table
for j in table_data.find_all('tr')[1:]:
        row_data = j.find_all('td')
        row = [tr.text for tr in row_data]
        length = len(df_2016)
        df_2016.loc[length] = row
df_2016
# Out:
#      RANK THIS WEEK \n                                RANK LAST WEEK  \
# 0       \n        1                                      \n        1
# 1       \n        2                                      \n        2
# 2       \n        3                                      \n        3
# 3       \n        4                                      \n        4
# 4      \n        T5                                     \n        T5
# ..              ...                                              ...
# 587   \n        588                                    \n        588
# 588  \n        T589                                   \n        T589
# 589  \n        T589                                   \n        T589
# 590   \n        591                                    \n        591
# 591   \n        592                                    \n        592
#
#             PLAYER NAME ROUNDS DISTANCE       TOURNAMENT ROUND HOLE COURSE
# 0     \nJustin Thomas\n     99      414  WGC-Bridgestone     2   16    036
# 1      \nBubba Watson\n     72      411   Hyundai T of C     3    6    656
# 2      \nRhein Gibson\n     58      406    Canadian Open     3   16    032
# 3         \nJason Day\n     76      404    Canadian Open     2   18    032
# 4      \nKevin Kisner\n     97      403   Hyundai T of C     2   17    656
# ..                  ...    ...      ...              ...   ...  ...    ...
# 587    \nSoren Hansen\n      2      269        U.S. Open     2    2    608
# 588     \nTyler Raber\n      2      268        U.S. Open     1    2    608
# 589  \nToru Taniguchi\n      2      268        U.S. Open     2    2    608
# 590      \nTom Watson\n      2      264          Masters     1    1    014
# 591   \nSSP Chawrasia\n      8      261  WGC-HSBC Champ.     1   18    766
#
# [592 rows x 9 columns]

# %%
#package imports
from bs4 import BeautifulSoup 
import lxml
import requests as request
import pandas as pd

#access the url and assign
url = 'https://www.pgatour.com/content/pgatour/stats/stat.159.y2015.html'
request.get(url)
page = request.get(url)

#use bs4 
soup = BeautifulSoup(page.text, 'html')

#find the table
table_data = soup.find('table', class_ ='table-styled')

#assign the headers
headers = []
for i in table_data.find_all('th'): #find the positions of the headers
    title = i.text #convert to text
    headers.append(title)

df_2015 = pd.DataFrame(columns = headers)

#grab the contents of the table
for j in table_data.find_all('tr')[1:]:
        row_data = j.find_all('td')
        row = [tr.text for tr in row_data]
        length = len(df_2015)
        df_2015.loc[length] = row
df_2015
# Out:
#      RANK THIS WEEK \n                                RANK LAST WEEK  \
# 0       \n        1                                      \n        1
# 1       \n        2                                      \n        2
# 2      \n        T3                                     \n        T3
# 3      \n        T3                                     \n        T3
# 4       \n        5                                      \n        5
# ..              ...                                              ...
# 197  \n        T897                                   \n        T897
# 198  \n        T897                                   \n        T897
# 199  \n        T897                                   \n        T897
# 200  \n        T968                                   \n        T967
# 201  \n        T968                                   \n        T967
#
#               PLAYER NAME ROUNDS DISTANCE       TOURNAMENT ROUND HOLE COURSE
# 0    \nBernd Wiesberger\n     33      428  WGC-Bridgestone     4   16    036
# 1       \nMarc Leishman\n     74      410  WGC-Bridgestone     4   16    036
# 2           \nJason Day\n     75      409   Hyundai T of C     1   12    656
# 3        \nGeoff Ogilvy\n     50      409   Hyundai T of C     1    7    656
# 4      \nDustin Johnson\n     75      406  WGC-Bridgestone     2   16    036
# ..                    ...    ...      ...              ...   ...  ...    ...
# 197      \nJohn Merrick\n     78      355    Canadian Open     1   18    032
# 198       \nChris Smith\n     29      355      AT&T Pebble     2   10    769
# 199       \nBoo Weekley\n     79      355        Sony Open     3    5    006
# 200      \nRyo Ishikawa\n     90      354    Valspar Champ     2   18    665
# 201      \nChris Naegel\n      6      354  John Deere Clas     3   10    669
#
# [202 rows x 9 columns]

# %%
#package imports
from bs4 import BeautifulSoup 
import lxml
import requests as request
import pandas as pd

#access the url and assign
url = 'https://www.pgatour.com/content/pgatour/stats/stat.159.y2014.html'
request.get(url)
page = request.get(url)

#use bs4 
soup = BeautifulSoup(page.text, 'html')

#find the table
table_data = soup.find('table', class_ ='table-styled')

#assign the headers
headers = []
for i in table_data.find_all('th'): #find the positions of the headers
    title = i.text #convert to text
    headers.append(title)

df_2014 = pd.DataFrame(columns = headers)

#grab the contents of the table
for j in table_data.find_all('tr')[1:]:
        row_data = j.find_all('td')
        row = [tr.text for tr in row_data]
        length = len(df_2014)
        df_2014.loc[length] = row
df_2014
# Out:
#      RANK THIS WEEK \n                                RANK LAST WEEK  \
# 0       \n        1                                      \n        1
# 1       \n        2                                      \n        2
# 2       \n        3                                      \n        3
# 3       \n        4                                      \n        4
# 4       \n        5                                      \n        5
# ..              ...                                              ...
# 189  \n        T907                                   \n        T900
# 190  \n        T907                                   \n        T900
# 191  \n        T907                                   \n        T900
# 192  \n        T907                                   \n        T900
# 193  \n        T907                                   \n        T900
#
#                        PLAYER NAME ROUNDS DISTANCE       TOURNAMENT ROUND  \
# 0                 \nBubba Watson\n     76      424  WGC-Bridgestone     3
# 1                 \nWebb Simpson\n     87      397   Hyundai T of C     4
# 2                \nJordan Spieth\n    102      396   Hyundai T of C     4
# 3    \nGonzalo Fernandez-Castaño\n     83      395  WGC-HSBC Champ.     4
# 4                  \nScott Brown\n    100      390   Hyundai T of C     4
# ..                             ...    ...      ...              ...   ...
# 189              \nSpencer Levin\n     59      349   Shriners Hosp.     4
# 190              \nPeter Malnati\n     48      349      AT&T Pebble     3
# 191                 \nBen Martin\n     80      349         The Open     2
# 192         \nTyrone Van Aswegen\n     79      349   Shriners Hosp.     1
# 193          \nHarold Varner III\n      6      349   Northern Trust     2
#
#     HOLE COURSE
# 0     16    036
# 1      7    656
# 2      7    656
# 3     14    766
# 4      7    656
# ..   ...    ...
# 189   11    538
# 190    6    769
# 191    1    724
# 192    2    538
# 193   15    500
#
# [194 rows x 9 columns]

# %%
#package imports
from bs4 import BeautifulSoup 
import lxml
import requests as request
import pandas as pd

#access the url and assign
url = 'https://www.pgatour.com/content/pgatour/stats/stat.159.y2013.html'
request.get(url)
page = request.get(url)

#use bs4 
soup = BeautifulSoup(page.text, 'html')

#find the table
table_data = soup.find('table', class_ ='table-styled')

#assign the headers
headers = []
for i in table_data.find_all('th'): #find the positions of the headers
    title = i.text #convert to text
    headers.append(title)

df_2013 = pd.DataFrame(columns = headers)

#grab the contents of the table
for j in table_data.find_all('tr')[1:]:
        row_data = j.find_all('td')
        row = [tr.text for tr in row_data]
        length = len(df_2013)
        df_2013.loc[length] = row
df_2013
# Out:
#      RANK THIS WEEK \n                                RANK LAST WEEK  \
# 0       \n        1                                      \n        1
# 1       \n        2                                      \n        2
# 2       \n        3                                      \n        3
# 3       \n        4                                      \n        4
# 4       \n        5                                      \n        5
# ..              ...                                              ...
# 196  \n        T950                                   \n        T939
# 197  \n        T950                                   \n        T939
# 198  \n        T950                                   \n        T939
# 199  \n        T950                                   \n        T939
# 200  \n        T950                                   \n        T939
#
#              PLAYER NAME ROUNDS DISTANCE       TOURNAMENT ROUND HOLE COURSE
# 0     \nPhil Mickelson\n     78      450     WGC-Cadillac     1   17    008
# 1       \nKyle Stanley\n     71      428   Hyundai T of C     2    7    656
# 2        \nIan Poulter\n     59      426   Hyundai T of C     1   12    656
# 3      \nGraham DeLaet\n     94      420    Shell Houston     4    8    729
# 4     \nCharlie Beljan\n     62      418   Hyundai T of C     2   12    656
# ..                   ...    ...      ...              ...   ...  ...    ...
# 196       \nBud Cauley\n     67      347        Sony Open     1   18    006
# 197    \nSergio Garcia\n     65      347   Northern Trust     3    3    500
# 198   \nScott Jamieson\n     10      347     WGC-Cadillac     4   14    008
# 199  \nJesper Parnevik\n     32      347  HP Byron Nelson     3    3    019
# 200     \nHeath Slocum\n     30      347      AT&T Pebble     2   10    769
#
# [201 rows x 9 columns]

# %%
#package imports
from bs4 import BeautifulSoup 
import lxml
import requests as request
import pandas as pd

#access the url and assign
url = 'https://www.pgatour.com/content/pgatour/stats/stat.159.y2012.html'
request.get(url)
page = request.get(url)

#use bs4 
soup = BeautifulSoup(page.text, 'html')

#find the table
table_data = soup.find('table', class_ ='table-styled')

#assign the headers
headers = []
for i in table_data.find_all('th'): #find the positions of the headers
    title = i.text #convert to text
    headers.append(title)

df_2012 = pd.DataFrame(columns = headers)

#grab the contents of the table
for j in table_data.find_all('tr')[1:]:
        row_data = j.find_all('td')
        row = [tr.text for tr in row_data]
        length = len(df_2012)
        df_2012.loc[length] = row
df_2012
# Out:
#     RANK THIS WEEK \n                                RANK LAST WEEK  \
# 0      \n        1                                      \n        1
# 1     \n        T2                                     \n        T2
# 2     \n        T2                                     \n        T2
# 3      \n        4                                      \n        4
# 4      \n        5                                      \n        5
# ..             ...                                              ...
# 575  \n        576                                    \n        576
# 576  \n        577                                    \n        577
# 577  \n        578                                    \n        578
# 578  \n        579                                    \n        579
# 579  \n        580                                    \n        580
#
#               PLAYER NAME ROUNDS DISTANCE       TOURNAMENT ROUND HOLE COURSE
# 0       \nGary Woodland\n     70      450   Hyundai T of C     1   18    656
# 1      \nKeegan Bradley\n     90      442  WGC-Bridgestone     2   16    036
# 2        \nBubba Watson\n     68      442  WGC-Bridgestone     3   16    036
# 3    \nLouis Oosthuizen\n     65      430  WGC-Bridgestone     3   16    036
# 4        \nKyle Stanley\n     86      429  WGC-Bridgestone     3   16    036
# ..                    ...    ...      ...              ...   ...  ...    ...
# 575        \nIan Keenan\n      2      260         The Open     1    2    539
# 576    \nMark Carnevale\n      1      256    True South Cl     1    9    609
# 577      \nMardan Mamat\n      1      252         The Open     1    2    539
# 578      \nBen Crenshaw\n      2      247          Masters     1    1    014
# 579   \nDarrell Kestner\n      2      244  PGA Championshi     2    2    697
#
# [580 rows x 9 columns]

# %%
#package imports
from bs4 import BeautifulSoup 
import lxml
import requests as request
import pandas as pd

#access the url and assign
url = 'https://www.pgatour.com/content/pgatour/stats/stat.159.y2011.html'
request.get(url)
page = request.get(url)

#use bs4 
soup = BeautifulSoup(page.text, 'html')

#find the table
table_data = soup.find('table', class_ ='table-styled')

#assign the headers
headers = []
for i in table_data.find_all('th'): #find the positions of the headers
    title = i.text #convert to text
    headers.append(title)

df_2011 = pd.DataFrame(columns = headers)

#grab the contents of the table
for j in table_data.find_all('tr')[1:]:
        row_data = j.find_all('td')
        row = [tr.text for tr in row_data]
        length = len(df_2011)
        df_2011.loc[length] = row
df_2011
# Out:
#     RANK THIS WEEK \n                                RANK LAST WEEK  \
# 0      \n        1                                      \n        1
# 1      \n        2                                      \n        2
# 2     \n        T3                                     \n        T3
# 3     \n        T3                                     \n        T3
# 4      \n        5                                      \n        5
# ..             ...                                              ...
# 574  \n        575                                    \n        575
# 575  \n        576                                    \n        576
# 576  \n        577                                    \n        577
# 577  \n        578                                    \n        578
# 578  \n        579                                    \n        579
#
#               PLAYER NAME ROUNDS DISTANCE       TOURNAMENT ROUND HOLE COURSE
# 0      \nDustin Johnson\n     72      463    Deutsche Bank     4    7    700
# 1        \nDerek Lamely\n     65      419   The Greenbrier     2    7    771
# 2         \nJ.B. Holmes\n     57      415       Texas Open     2   10    770
# 3        \nBubba Watson\n     85      415  WGC-Bridgestone     3   16    036
# 4       \nGary Woodland\n     93      409  HP Byron Nelson     3    1    019
# ..                    ...    ...      ...              ...   ...  ...    ...
# 574          \nLion Kim\n      2      273          Masters     2    1    014
# 575  \nMichael Campbell\n      2      272        U.S. Open     2    1    024
# 576      \nBeau Hossler\n      2      270        U.S. Open     1    1    024
# 577        \nLarry Mize\n      2      269          Masters     2    1    014
# 578      \nBen Crenshaw\n      2      258          Masters     2    1    014
#
# [579 rows x 9 columns]

# %%
total = [df_2021, df_2020, df_2019, df_2018, df_2017, df_2016, df_2015, df_2014, df_2013, df_2012, df_2011]

result = pd.concat(total)

result
# Out:
#     RANK THIS WEEK \n                                RANK LAST WEEK  \
# 0      \n        1                                      \n        1
# 1      \n        2                                      \n        2
# 2      \n        3                                      \n        3
# 3      \n        4                                      \n        4
# 4      \n        5                                      \n        5
# ..             ...                                              ...
# 574  \n        575                                    \n        575
# 575  \n        576                                    \n        576
# 576  \n        577                                    \n        577
# 577  \n        578                                    \n        578
# 578  \n        579                                    \n        579
#
#                PLAYER NAME ROUNDS DISTANCE       TOURNAMENT ROUND HOLE COURSE
# 0         \nLee Westwood\n     65      425     Byron Nelson     3    8    894
# 1        \nCameron Champ\n     79      424           Sentry     4    7    656
# 2          \nConnor Syme\n      2      423  U.S. Open(2020)     2    4    891
# 3       \nDustin Johnson\n     75      419  U.S. Open(2020)     4    9    891
# 4    \nBryson DeChambeau\n     83      414           Sentry     2   12    656
# ..                     ...    ...      ...              ...   ...  ...    ...
# 574           \nLion Kim\n      2      273          Masters     2    1    014
# 575   \nMichael Campbell\n      2      272        U.S. Open     2    1    024
# 576       \nBeau Hossler\n      2      270        U.S. Open     1    1    024
# 577         \nLarry Mize\n      2      269          Masters     2    1    014
# 578       \nBen Crenshaw\n      2      258          Masters     2    1    014
#
# [5322 rows x 9 columns]

# %%
#clean Player name 
player_name = result['PLAYER NAME'].str.replace('\n','')

#convert distance from object to int
distance = result['DISTANCE']
distance = pd.to_numeric(distance)
#convert distance from object to int
rounds = result['ROUNDS']
rounds = pd.to_numeric(rounds)

# %%
result.columns = [i.replace('\n', '').replace(u'\xa0', u' ').strip() for i in result.columns]
result['RANK THIS WEEK'].str.replace('\n', '').str.replace('T', '')
result['RANK THIS WEEK'] = result['RANK THIS WEEK'].str.extract('(\d+)')
#cleaning each via a for loop
for i in result.columns:
    result[i] = result[i].str.replace('\n', '')
    
result
# Out:
#     RANK THIS WEEK RANK LAST WEEK        PLAYER NAME ROUNDS DISTANCE  \
# 0                1              1       Lee Westwood     65      425
# 1                2              2      Cameron Champ     79      424
# 2                3              3        Connor Syme      2      423
# 3                4              4     Dustin Johnson     75      419
# 4                5              5  Bryson DeChambeau     83      414
# ..             ...            ...                ...    ...      ...
# 574            575            575           Lion Kim      2      273
# 575            576            576   Michael Campbell      2      272
# 576            577            577       Beau Hossler      2      270
# 577            578            578         Larry Mize      2      269
# 578            579            579       Ben Crenshaw      2      258
#
#           TOURNAMENT ROUND HOLE COURSE
# 0       Byron Nelson     3    8    894
# 1             Sentry     4    7    656
# 2    U.S. Open(2020)     2    4    891
# 3    U.S. Open(2020)     4    9    891
# 4             Sentry     2   12    656
# ..               ...   ...  ...    ...
# 574          Masters     2    1    014
# 575        U.S. Open     2    1    024
# 576        U.S. Open     1    1    024
# 577          Masters     2    1    014
# 578          Masters     2    1    014
#
# [5322 rows x 9 columns]

# %%
del result['RANK THIS WEEK']
del result['RANK LAST WEEK']

# %%
result.to_excel('PGA_Final.xlsx')
